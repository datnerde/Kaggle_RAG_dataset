# %% [markdown]
# This notebook is built on top of the [data minification one](https://www.kaggle.com/jiaofenx/ashrae-data-minification).

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os, gc, sys, warnings, random, math, datetime, psutil, pickle

from tqdm import tqdm_notebook as tqdm

from sklearn.model_selection import KFold, StratifiedKFold
import lightgbm as lgb

train = pd.read_pickle('../input/ashraedataminification/train_df.pkl')
test = pd.read_pickle('../input/ashraedataminification/test_df.pkl')
target = 'meter_reading'

## Simple "Memory profilers" to see memory usage
def get_memory_usage():
    return np.round(psutil.Process(os.getpid()).memory_info()[0]/2.**30, 2) 
print('Memory in Gb', get_memory_usage())
# Out:
# Memory in Gb 3.62

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        if col!=target:
            col_type = df[col].dtypes
            if col_type in numerics:
                c_min = df[col].min()
                c_max = df[col].max()
                if str(col_type)[:3] == 'int':
                    if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)  
                else:
                    if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                        df[col] = df[col].astype(np.float16)
                    elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                        df[col] = df[col].astype(np.float32)
                    else:
                        df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
gc.collect()
print('Memory in Gb', get_memory_usage())
# Out:
# Mem. usage decreased to 694.06 Mb (40.0% reduction)
# Mem. usage decreased to 1272.51 Mb (42.9% reduction)
# Memory in Gb 2.24

# %%
# force the model to use the weather data instead of dates, to avoid overfitting to the past history
features = [col for col in train.columns if col not in [target, 'DT_Y', 'DT_M', 'DT_W', 'DT_D', 'DT_day_month', 'DT_week_month']]
folds = 4
seed = 42
kf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
models = []

## stratify data by building_id
for tr_idx, val_idx in tqdm(kf.split(train, train['building_id']), total=folds):
    tr_x, tr_y = train[features].iloc[tr_idx], train[target][tr_idx]
    vl_x, vl_y = train[features].iloc[val_idx], train[target][val_idx]
    print({'train size':len(tr_x), 'eval size':len(vl_x)})

    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)  
    clf = lgb.LGBMRegressor(n_estimators=6000,
                            learning_rate=0.28,
                            feature_fraction=0.9,
                            subsample=0.2,  # batches of 20% of the data
                            subsample_freq=1,
                            num_leaves=20,
                            metric='rmse')
    clf.fit(tr_x, tr_y,
            eval_set=[(vl_x, vl_y)],
            early_stopping_rounds=50,
            verbose=200)
    models.append(clf)
    
gc.collect()
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# {'train size': 15161663, 'eval size': 5054437}
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's rmse: 1.16744
# [400]	valid_0's rmse: 1.06617
# [600]	valid_0's rmse: 1.01353
# [800]	valid_0's rmse: 0.980943
# [1000]	valid_0's rmse: 0.955774
# [1200]	valid_0's rmse: 0.938899
# [1400]	valid_0's rmse: 0.923898
# [1600]	valid_0's rmse: 0.914128
# [1800]	valid_0's rmse: 0.904196
# [2000]	valid_0's rmse: 0.896379
# [2200]	valid_0's rmse: 0.888763
# [2400]	valid_0's rmse: 0.882155
# [2600]	valid_0's rmse: 0.876678
# [2800]	valid_0's rmse: 0.871782
# [3000]	valid_0's rmse: 0.86746
# [3200]	valid_0's rmse: 0.863281
# [3400]	valid_0's rmse: 0.859154
# [3600]	valid_0's rmse: 0.856589
# [3800]	valid_0's rmse: 0.853535
# [4000]	valid_0's rmse: 0.850515
# [4200]	valid_0's rmse: 0.847853
# [4400]	valid_0's rmse: 0.845469
# [4600]	valid_0's rmse: 0.843225
# [4800]	valid_0's rmse: 0.841115
# [5000]	valid_0's rmse: 0.839204
# [5200]	valid_0's rmse: 0.837164
# [5400]	valid_0's rmse: 0.835155
# [5600]	valid_0's rmse: 0.833545
# [5800]	valid_0's rmse: 0.831534
# [6000]	valid_0's rmse: 0.829752
# Did not meet early stopping. Best iteration is:
# [6000]	valid_0's rmse: 0.829752
# {'train size': 15161832, 'eval size': 5054268}
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's rmse: 1.17367
# [400]	valid_0's rmse: 1.07032
# [600]	valid_0's rmse: 1.01598
# [800]	valid_0's rmse: 0.982392
# [1000]	valid_0's rmse: 0.960397
# [1200]	valid_0's rmse: 0.940978
# [1400]	valid_0's rmse: 0.926801
# [1600]	valid_0's rmse: 0.916153
# [1800]	valid_0's rmse: 0.90584
# [2000]	valid_0's rmse: 0.896693
# [2200]	valid_0's rmse: 0.888788
# [2400]	valid_0's rmse: 0.882406
# [2600]	valid_0's rmse: 0.875718
# [2800]	valid_0's rmse: 0.871058
# [3000]	valid_0's rmse: 0.86618
# [3200]	valid_0's rmse: 0.861697
# [3400]	valid_0's rmse: 0.858415
# [3600]	valid_0's rmse: 0.854795
# [3800]	valid_0's rmse: 0.851808
# [4000]	valid_0's rmse: 0.848678
# [4200]	valid_0's rmse: 0.846559
# [4400]	valid_0's rmse: 0.843777
# [4600]	valid_0's rmse: 0.841168
# [4800]	valid_0's rmse: 0.83898
# [5000]	valid_0's rmse: 0.836992
# [5200]	valid_0's rmse: 0.834928
# [5400]	valid_0's rmse: 0.832978
# [5600]	valid_0's rmse: 0.831426
# [5800]	valid_0's rmse: 0.830328
# [6000]	valid_0's rmse: 0.829017
# Did not meet early stopping. Best iteration is:
# [5996]	valid_0's rmse: 0.829014
# {'train size': 15162246, 'eval size': 5053854}
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's rmse: 1.17132
# [400]	valid_0's rmse: 1.06918
# [600]	valid_0's rmse: 1.0151
# [800]	valid_0's rmse: 0.982003
# [1000]	valid_0's rmse: 0.958315
# [1200]	valid_0's rmse: 0.941063
# [1400]	valid_0's rmse: 0.927276
# [1600]	valid_0's rmse: 0.914635
# [1800]	valid_0's rmse: 0.904034
# [2000]	valid_0's rmse: 0.8959
# [2200]	valid_0's rmse: 0.888043
# [2400]	valid_0's rmse: 0.882168
# [2600]	valid_0's rmse: 0.875945
# [2800]	valid_0's rmse: 0.870165
# [3000]	valid_0's rmse: 0.866123
# [3200]	valid_0's rmse: 0.862488
# [3400]	valid_0's rmse: 0.858387
# [3600]	valid_0's rmse: 0.854958
# [3800]	valid_0's rmse: 0.851605
# [4000]	valid_0's rmse: 0.848922
# [4200]	valid_0's rmse: 0.846235
# [4400]	valid_0's rmse: 0.843615
# [4600]	valid_0's rmse: 0.841321
# [4800]	valid_0's rmse: 0.839525
# [5000]	valid_0's rmse: 0.83777
# [5200]	valid_0's rmse: 0.835848
# [5400]	valid_0's rmse: 0.834016
# [5600]	valid_0's rmse: 0.832633
# [5800]	valid_0's rmse: 0.830878
# [6000]	valid_0's rmse: 0.829178
# Did not meet early stopping. Best iteration is:
# [5996]	valid_0's rmse: 0.82917
# {'train size': 15162559, 'eval size': 5053541}
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's rmse: 1.17183
# [400]	valid_0's rmse: 1.07101
# [600]	valid_0's rmse: 1.01794
# [800]	valid_0's rmse: 0.98503
# [1000]	valid_0's rmse: 0.961459
# [1200]	valid_0's rmse: 0.941896
# [1400]	valid_0's rmse: 0.927417
# [1600]	valid_0's rmse: 0.914955
# [1800]	valid_0's rmse: 0.90541
# [2000]	valid_0's rmse: 0.896557
# [2200]	valid_0's rmse: 0.888597
# [2400]	valid_0's rmse: 0.881776
# [2600]	valid_0's rmse: 0.876265
# [2800]	valid_0's rmse: 0.870872
# [3000]	valid_0's rmse: 0.866579
# [3200]	valid_0's rmse: 0.862449
# [3400]	valid_0's rmse: 0.858165
# [3600]	valid_0's rmse: 0.854752
# [3800]	valid_0's rmse: 0.851327
# [4000]	valid_0's rmse: 0.84834
# [4200]	valid_0's rmse: 0.845858
# [4400]	valid_0's rmse: 0.84346
# [4600]	valid_0's rmse: 0.84137
# [4800]	valid_0's rmse: 0.839366
# [5000]	valid_0's rmse: 0.837789
# [5200]	valid_0's rmse: 0.836092
# [5400]	valid_0's rmse: 0.834546
# [5600]	valid_0's rmse: 0.83288
# [5800]	valid_0's rmse: 0.831365
# [6000]	valid_0's rmse: 0.830047
# Did not meet early stopping. Best iteration is:
# [6000]	valid_0's rmse: 0.830047
# 244

# %%
# split test data into batches
set_size = len(test)
iterations = 50
batch_size = set_size // iterations

meter_reading = []
for i in tqdm(range(iterations)):
    pos = i*batch_size
    fold_preds = [np.expm1(model.predict(test[features].iloc[pos : pos+batch_size])) for model in models]
    meter_reading.extend(np.mean(fold_preds, axis=0))
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
submission = pd.read_csv('../input/ashrae-energy-prediction/sample_submission.csv')
submission['meter_reading'] = np.clip(meter_reading, a_min=0, a_max=None) # clip min at zero
submission.to_csv('submission.csv', index=False)
